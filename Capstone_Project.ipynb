# %% [markdown]
# # **Capstone Notebook**
#
# This is a notebook for my data science capstone course and project

# %%
# !pip install pandas
# !pip install numpy

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
